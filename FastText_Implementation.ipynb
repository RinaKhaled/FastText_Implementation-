# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from gensim.models.fasttext import FastText # build and train Fast Text model
from gensim.models import Word2Vec # to Save and Load Word2Vec models
from gensim.models.fasttext import load_facebook_model
from textblob import Word
import spacy
import numpy as np
import nltk
import string
from nltk.stem.wordnet import WordNetLemmatizer

# %% [markdown]
# ## Preprocessing

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def textPreprocessing(text):

  # Noramlization
  text = text.lower()
  text = re.sub(r'\n', '', text) # Remove new lines (\n)
  # Remove Punctuation
  translator = str.maketrans('', '', string.punctuation)
  text = text.translate(translator)

  # Tokenization
  text = text.split()
  # Removing Stop Words
  useless_words = nltk.corpus.stopwords.words("english")
  useless_words = useless_words + ['«', '»','©']
  text = [word for word in text if not word in useless_words]

  # # Cleaning
  # text = list(set(text))
  # Removing Numbers and words with Numbers
  text_filtered = [re.sub(r'\w*\d\w*', '', w) for w in text]
  text_filtered = [re.sub(r'\d', '', w) for w in text_filtered]
  text_filtered = [re.sub(r'\s+[a-zA-Z]\s+', '', w) for w in text_filtered ]
  
  
  # Removing empty strings
  text_filtered = [x for x in text_filtered if x != '']

  # Lemmatization
  nlp = spacy.load("en_core_web_sm")
  text_lem=[]
  for wordq in text_filtered:
    s=nlp(wordq)
    se = [token.lemma_ for token in s][0]
#     word = Word(se)
#     ss=word.lemmatize("v")
    # print(f"{wordq} ---> {word} ------> ",ss )
    text_lem.append(se)
  text_lem = [word for word in text_lem if len(word) > 2]
  # Get Unique Words
  text_lem = list(set(text_lem))

  return text_lem

# %% [markdown]
# ## Load Dataset

# %%
yelp_datafile = pd.read_json("/kaggle/input/yelp-dataset/yelp_academic_dataset_tip.json", lines=True)

# %%
text=np.array(yelp_datafile['text'][0:1000])

# %%
listText=list(text)

# %% [markdown]
# ## Apply Preprocessing

# %%
Preprocessed_Text=[textPreprocessing(texts) for texts in listText]

# %% [markdown]
# ## FastText

# %%
def train_Fasttext(word_tokens,embedding_size,window_size,min_word,down_sampling,Save_model_filename):
    
  fast_Text_model = FastText(word_tokens,
                                 vector_size=embedding_size, # Dimensionality of the word vectors. ,
                                 window=window_size,
                                 min_count=min_word, # The model ignores all words with total frequency lower than this.
                                 sample=down_sampling, # threshold which higher-frequency words are randomly down sampled
                                 workers = 4, # Num threads to train the model (faster training with multicore comp.)
                                 sg=1, # Training algorithm: skip-gram if sg=1, otherwise CBOW.
                                 epochs=100) # Number of iterations (epochs) over the corpus
    
  fast_Text_model.save(Save_model_filename) # Save fastText gensim model

# %%
embedding_size = 300
window_size = 5
min_word = 5
down_sampling = 1e-2
train_Fasttext(Preprocessed_Text,embedding_size,window_size,min_word,down_sampling,'/kaggle/working/model')

# %%
fast_Text_model = Word2Vec.load('/kaggle/working/model')

# %%
wwords=fast_Text_model.wv.index_to_key

# %%
import random

testno=20

random_numbers = random.sample(range(len(wwords)), testno)

# print(random_numbers)

# %%
random_numbers=[76, 78, 167, 95, 165, 149, 101, 89, 80, 246, 34, 142, 247, 252, 38, 154, 49, 133, 57, 135]
# Out:
# [76,
#  78,
#  167,
#  95,
#  165,
#  149,
#  101,
#  89,
#  80,
#  246,
#  34,
#  142,
#  247,
#  252,
#  38,
#  154,
#  49,
#  133,
#  57,
#  135]

# %%
simopp=[]
simoppwords=[]
for i in random_numbers:
    ww=wwords[i]
    similarwords=fast_Text_model.wv.most_similar(ww, topn=10)
    oppositewords=fast_Text_model.wv.most_similar(negative=ww, topn=10)
    print('similar words of',ww)
    simopp.append(ww)
    a=[]
    b=[]
    for similar,percent in similarwords:
        print('(',similar,') similarity:',percent)
        a.append(similar)
    print('opposite words of',ww)
    for opp,percent in oppositewords:
        print('(',opp,') similarity:',percent)
        b.append(opp)
    simoppwords.append(a)
    simoppwords.append(b)
    print('....................................................')
# Out:
# similar words of onion
# ( pickle ) similarity: 0.678815484046936
# ( enjoy ) similarity: 0.6416696906089783
# ( beef ) similarity: 0.6304275393486023
# ( option ) similarity: 0.6120758652687073
# ( cheese ) similarity: 0.5918620228767395
# ( portion ) similarity: 0.5595524311065674
# ( chili ) similarity: 0.5392857193946838
# ( must ) similarity: 0.5369822978973389
# ( wednesday ) similarity: 0.5224050879478455
# ( choice ) similarity: 0.5183122754096985
# opposite words of onion
# ( sushi ) similarity: 0.0032931293826550245
# ( nice ) similarity: -0.0016629263991490006
# ( place ) similarity: -0.016874173656105995
# ( sure ) similarity: -0.020855389535427094
# ( wait ) similarity: -0.02393491379916668
# ( yet ) similarity: -0.03249121084809303
# ( office ) similarity: -0.036814603954553604
# ( that ) similarity: -0.04380433261394501
# ( get ) similarity: -0.05201029032468796
# ( seat ) similarity: -0.055999789386987686
# ....................................................
# similar words of home
# ( town ) similarity: 0.5559900403022766
# ( authentic ) similarity: 0.5419125556945801
# ( pack ) similarity: 0.5384443998336792
# ( eat ) similarity: 0.5298608541488647
# ( dine ) similarity: 0.5262236595153809
# ( lot ) similarity: 0.5093904137611389
# ( come ) similarity: 0.5076934695243835
# ( selection ) similarity: 0.5046653151512146
# ( restaurant ) similarity: 0.5042951703071594
# ( style ) similarity: 0.5035369396209717
# opposite words of home
# ( fry ) similarity: 0.03320495784282684
# ( offer ) similarity: 0.014796102419495583
# ( work ) similarity: 0.0024206959642469883
# ( white ) similarity: 0.001440278603695333
# ( class ) similarity: -0.006334904581308365
# ( cream ) similarity: -0.007347384002059698
# ( shrimp ) similarity: -0.008698999881744385
# ( yum ) similarity: -0.013868811540305614
# ( busy ) similarity: -0.017724858596920967
# ( ice ) similarity: -0.042896613478660583
# ....................................................
# similar words of park
# ( parking ) similarity: 0.7520781755447388
# ( cuban ) similarity: 0.6335368156433105
# ( plus ) similarity: 0.6215663552284241
# ( bean ) similarity: 0.588441014289856
# ( option ) similarity: 0.5669055581092834
# ( next ) similarity: 0.5446146130561829
# ( patio ) similarity: 0.5333603024482727
# ( kid ) similarity: 0.5111842155456543
# ( dog ) similarity: 0.50138920545578
# ( item ) similarity: 0.49973630905151367
# opposite words of park
# ( beer ) similarity: 0.044771626591682434
# ( yummy ) similarity: 0.039553944021463394
# ( monday ) similarity: 0.0053450665436685085
# ( server ) similarity: -0.0015696316258981824
# ( end ) similarity: -0.011879107914865017
# ( bad ) similarity: -0.024298589676618576
# ( look ) similarity: -0.02589261345565319
# ( thank ) similarity: -0.03327758237719536
# ( taste ) similarity: -0.03496373072266579
# ( fish ) similarity: -0.03710781782865524
# ....................................................
# similar words of wait
# ( ahead ) similarity: 0.6398207545280457
# ( less ) similarity: 0.5826009511947632
# ( minute ) similarity: 0.5318911671638489
# ( sure ) similarity: 0.49498286843299866
# ( seat ) similarity: 0.4540310204029083
# ( huge ) similarity: 0.4398660957813263
# ( long ) similarity: 0.43655088543891907
# ( use ) similarity: 0.4316377639770508
# ( quick ) similarity: 0.43009987473487854
# ( else ) similarity: 0.4271160662174225
# opposite words of wait
# ( cake ) similarity: 0.049413107335567474
# ( cold ) similarity: 0.008840491995215416
# ( store ) similarity: -0.0018305109115317464
# ( spring ) similarity: -0.0066075106151402
# ( roll ) similarity: -0.0067075942642986774
# ( fast ) similarity: -0.02037772350013256
# ( onion ) similarity: -0.02393493242561817
# ( much ) similarity: -0.026508554816246033
# ( try ) similarity: -0.03770184516906738
# ( start ) similarity: -0.03893081471323967
# ....................................................
# similar words of brew
# ( cuban ) similarity: 0.793228030204773
# ( bean ) similarity: 0.7068279981613159
# ( breakfast ) similarity: 0.6107521057128906
# ( option ) similarity: 0.6061674952507019
# ( italian ) similarity: 0.5908680558204651
# ( bread ) similarity: 0.5796067714691162
# ( large ) similarity: 0.5749373435974121
# ( sandwich ) similarity: 0.572853684425354
# ( family ) similarity: 0.5691857933998108
# ( coffee ) similarity: 0.5547195076942444
# opposite words of brew
# ( would ) similarity: 0.038390129804611206
# ( could ) similarity: 0.01549252774566412
# ( show ) similarity: -0.03718247637152672
# ( say ) similarity: -0.04043959453701973
# ( street ) similarity: -0.04286791384220123
# ( get ) similarity: -0.0442969836294651
# ( helpful ) similarity: -0.046826887875795364
# ( use ) similarity: -0.04998936504125595
# ( back ) similarity: -0.05189048871397972
# ( know ) similarity: -0.055435117334127426
# ....................................................
# similar words of brunch
# ( lunch ) similarity: 0.6175557971000671
# ( frozen ) similarity: 0.6084777116775513
# ( early ) similarity: 0.5482337474822998
# ( starbuck ) similarity: 0.5342708230018616
# ( beautiful ) similarity: 0.5240557193756104
# ( tip ) similarity: 0.5204894542694092
# ( end ) similarity: 0.5159720182418823
# ( must ) similarity: 0.5142133235931396
# ( many ) similarity: 0.5033904910087585
# ( saturday ) similarity: 0.4955233335494995
# opposite words of brunch
# ( delicious ) similarity: 0.02640759013593197
# ( item ) similarity: 0.024043304845690727
# ( like ) similarity: 0.019596582278609276
# ( rice ) similarity: 0.017567690461874008
# ( portion ) similarity: 0.0015569091774523258
# ( good ) similarity: -0.021964168176054955
# ( clean ) similarity: -0.028060685843229294
# ( new ) similarity: -0.04274445399641991
# ( dessert ) similarity: -0.04994344711303711
# ( ever ) similarity: -0.05772950500249863
# ....................................................
# similar words of way
# ( else ) similarity: 0.644793689250946
# ( thursday ) similarity: 0.6030415296554565
# ( day ) similarity: 0.5940549969673157
# ( say ) similarity: 0.5743210315704346
# ( start ) similarity: 0.5655136108398438
# ( red ) similarity: 0.5499321818351746
# ( fish ) similarity: 0.5466403365135193
# ( monday ) similarity: 0.5420598983764648
# ( today ) similarity: 0.5287056565284729
# ( omg ) similarity: 0.5205463767051697
# opposite words of way
# ( appetizer ) similarity: 0.07797062397003174
# ( excellent ) similarity: 0.05255536735057831
# ( large ) similarity: 0.03330347314476967
# ( area ) similarity: 0.021955281496047974
# ( ask ) similarity: 0.006060909014195204
# ( selection ) similarity: -0.009993660263717175
# ( seafood ) similarity: -0.02249116264283657
# ( salad ) similarity: -0.027106329798698425
# ( section ) similarity: -0.03099999763071537
# ( sell ) similarity: -0.036377642303705215
# ....................................................
# similar words of salad
# ( soup ) similarity: 0.5590632557868958
# ( sauce ) similarity: 0.5193143486976624
# ( chicken ) similarity: 0.4860920310020447
# ( quick ) similarity: 0.4762343466281891
# ( rib ) similarity: 0.47474247217178345
# ( crispy ) similarity: 0.467855304479599
# ( seafood ) similarity: 0.45469406247138977
# ( super ) similarity: 0.4487532675266266
# ( sandwich ) similarity: 0.44564855098724365
# ( yum ) similarity: 0.43113189935684204
# opposite words of salad
# ( could ) similarity: 0.09227900952100754
# ( open ) similarity: 0.05151571333408356
# ( time ) similarity: 0.03895801678299904
# ( want ) similarity: 0.029517587274312973
# ( make ) similarity: 0.028232712298631668
# ( owner ) similarity: -0.02261115238070488
# ( bad ) similarity: -0.025958364829421043
# ( night ) similarity: -0.02597659081220627
# ( way ) similarity: -0.027106331661343575
# ( sign ) similarity: -0.02725943736732006
# ....................................................
# similar words of sweet
# ( sandwich ) similarity: 0.6260572671890259
# ( pepper ) similarity: 0.5461061000823975
# ( pickle ) similarity: 0.5414159893989563
# ( steak ) similarity: 0.5307896733283997
# ( offer ) similarity: 0.5214211344718933
# ( town ) similarity: 0.5152208209037781
# ( meet ) similarity: 0.5121553540229797
# ( cuban ) similarity: 0.5048313140869141
# ( line ) similarity: 0.5035001635551453
# ( bread ) similarity: 0.5024756193161011
# opposite words of sweet
# ( yelp ) similarity: 0.0536506213247776
# ( friday ) similarity: 0.018199684098362923
# ( day ) similarity: 0.012457082979381084
# ( favorite ) similarity: 0.0011158720590174198
# ( monday ) similarity: -0.008526220917701721
# ( many ) similarity: -0.02214866876602173
# ( margarita ) similarity: -0.022947292774915695
# ( thursday ) similarity: -0.026320429518818855
# ( perfect ) similarity: -0.028271082788705826
# ( food ) similarity: -0.029726864770054817
# ....................................................
# similar words of actually
# ( monday ) similarity: 0.6543468832969666
# ( sunday ) similarity: 0.6316278576850891
# ( long ) similarity: 0.56534343957901
# ( anything ) similarity: 0.5606070756912231
# ( street ) similarity: 0.5355796813964844
# ( thank ) similarity: 0.5212022066116333
# ( music ) similarity: 0.5198418498039246
# ( everything ) similarity: 0.5093240737915039
# ( seem ) similarity: 0.5042500495910645
# ( open ) similarity: 0.5018244981765747
# opposite words of actually
# ( bread ) similarity: 0.05883035436272621
# ( fry ) similarity: 0.0025610802695155144
# ( side ) similarity: 0.001736328937113285
# ( sauce ) similarity: 0.001386441639624536
# ( week ) similarity: -0.009450421668589115
# ( good ) similarity: -0.015505342744290829
# ( sandwich ) similarity: -0.019332174211740494
# ( cold ) similarity: -0.0225763488560915
# ( crispy ) similarity: -0.02572927623987198
# ( steak ) similarity: -0.037328820675611496
# ....................................................
# similar words of selection
# ( section ) similarity: 0.7809990644454956
# ( sell ) similarity: 0.5868996381759644
# ( inside ) similarity: 0.5820796489715576
# ( tea ) similarity: 0.5417247414588928
# ( margarita ) similarity: 0.5268473625183105
# ( fantastic ) similarity: 0.5223180651664734
# ( highly ) similarity: 0.5164657235145569
# ( area ) similarity: 0.5141002535820007
# ( location ) similarity: 0.506903350353241
# ( sushi ) similarity: 0.5055646300315857
# opposite words of selection
# ( line ) similarity: 0.017558660358190536
# ( else ) similarity: 0.017337175086140633
# ( saturday ) similarity: 0.007667774800211191
# ( red ) similarity: -0.006098428275436163
# ( way ) similarity: -0.009993660263717175
# ( cut ) similarity: -0.013105948455631733
# ( show ) similarity: -0.020285651087760925
# ( busy ) similarity: -0.027644917368888855
# ( fry ) similarity: -0.034785088151693344
# ( use ) similarity: -0.03497137874364853
# ....................................................
# similar words of everything
# ( anything ) similarity: 0.7939545512199402
# ( every ) similarity: 0.7372115850448608
# ( even ) similarity: 0.5931277275085449
# ( nothing ) similarity: 0.5908450484275818
# ( event ) similarity: 0.5339642763137817
# ( ever ) similarity: 0.5318729877471924
# ( thing ) similarity: 0.5195440649986267
# ( actually ) similarity: 0.5093239545822144
# ( wing ) similarity: 0.4870468080043793
# ( spring ) similarity: 0.48531612753868103
# opposite words of everything
# ( steak ) similarity: 0.042883653193712234
# ( line ) similarity: 0.040629591792821884
# ( lunch ) similarity: 0.013485281728208065
# ( offer ) similarity: 0.012189554050564766
# ( bread ) similarity: 0.0020108181051909924
# ( order ) similarity: -0.016183113679289818
# ( time ) similarity: -0.03304654359817505
# ( end ) similarity: -0.0345325730741024
# ( red ) similarity: -0.03517609462141991
# ( frozen ) similarity: -0.04590300843119621
# ....................................................
# similar words of like
# ( know ) similarity: 0.47993776202201843
# ( bbq ) similarity: 0.45683708786964417
# ( change ) similarity: 0.4358392059803009
# ( huge ) similarity: 0.40985703468322754
# ( pepper ) similarity: 0.3984593152999878
# ( tap ) similarity: 0.36441296339035034
# ( would ) similarity: 0.36309510469436646
# ( red ) similarity: 0.35563766956329346
# ( little ) similarity: 0.35275256633758545
# ( seat ) similarity: 0.3511035144329071
# opposite words of like
# ( always ) similarity: 0.05790252611041069
# ( family ) similarity: 0.027679570019245148
# ( brunch ) similarity: 0.019596576690673828
# ( free ) similarity: 0.01609634794294834
# ( early ) similarity: 0.012392290867865086
# ( large ) similarity: -0.005166839808225632
# ( hot ) similarity: -0.008171064779162407
# ( crowd ) similarity: -0.008601298555731773
# ( atmosphere ) similarity: -0.011866386979818344
# ( every ) similarity: -0.0236191526055336
# ....................................................
# similar words of step
# ( year ) similarity: 0.6309464573860168
# ( helpful ) similarity: 0.5741235613822937
# ( starbuck ) similarity: 0.5544229745864868
# ( staff ) similarity: 0.5527868866920471
# ( stop ) similarity: 0.5517240166664124
# ( ago ) similarity: 0.5509513020515442
# ( beautiful ) similarity: 0.550776481628418
# ( cream ) similarity: 0.5295106768608093
# ( yet ) similarity: 0.5262466073036194
# ( beef ) similarity: 0.5236116051673889
# opposite words of step
# ( tasty ) similarity: 0.028186282142996788
# ( fill ) similarity: 0.015176452696323395
# ( pretty ) similarity: 0.014338991604745388
# ( come ) similarity: 0.01028602197766304
# ( hot ) similarity: 0.004760498646646738
# ( service ) similarity: 5.612454697256908e-05
# ( eat ) similarity: -0.004595755599439144
# ( half ) similarity: -0.008646257221698761
# ( dinner ) similarity: -0.027079520747065544
# ( town ) similarity: -0.048741087317466736
# ....................................................
# similar words of quick
# ( snack ) similarity: 0.5772630572319031
# ( fill ) similarity: 0.5369185209274292
# ( offer ) similarity: 0.5225018858909607
# ( busy ) similarity: 0.5003849267959595
# ( ahead ) similarity: 0.48695239424705505
# ( half ) similarity: 0.48105567693710327
# ( pretty ) similarity: 0.4782518148422241
# ( salad ) similarity: 0.47623443603515625
# ( cash ) similarity: 0.47201645374298096
# ( less ) similarity: 0.446172297000885
# opposite words of quick
# ( bad ) similarity: 0.07736291736364365
# ( lot ) similarity: 0.06544292718172073
# ( patio ) similarity: 0.011832593008875847
# ( make ) similarity: -0.0372975692152977
# ( yes ) similarity: -0.04148431867361069
# ( one ) similarity: -0.041997991502285004
# ( home ) similarity: -0.049696195870637894
# ( plus ) similarity: -0.05373072624206543
# ( town ) similarity: -0.054385408759117126
# ( location ) similarity: -0.05838128924369812
# ....................................................
# similar words of drink
# ( patio ) similarity: 0.5592235922813416
# ( beef ) similarity: 0.5209482908248901
# ( margarita ) similarity: 0.5104866027832031
# ( live ) similarity: 0.492754191160202
# ( rib ) similarity: 0.4819798171520233
# ( large ) similarity: 0.4795505106449127
# ( actually ) similarity: 0.47197553515434265
# ( half ) similarity: 0.45989686250686646
# ( music ) similarity: 0.4332723617553711
# ( style ) similarity: 0.42801281809806824
# opposite words of drink
# ( thing ) similarity: 0.04385727643966675
# ( say ) similarity: 0.012310193851590157
# ( take ) similarity: 0.004557646345347166
# ( try ) similarity: -0.02545103244483471
# ( back ) similarity: -0.030554290860891342
# ( every ) similarity: -0.0388093963265419
# ( place ) similarity: -0.04070815071463585
# ( would ) similarity: -0.04566033184528351
# ( two ) similarity: -0.047944117337465286
# ( appetizer ) similarity: -0.050433315336704254
# ....................................................
# similar words of sunday
# ( day ) similarity: 0.6938888430595398
# ( monday ) similarity: 0.6690243482589722
# ( actually ) similarity: 0.6316278576850891
# ( sign ) similarity: 0.5671959519386292
# ( location ) similarity: 0.5578201413154602
# ( check ) similarity: 0.5525152683258057
# ( saturday ) similarity: 0.5524923801422119
# ( open ) similarity: 0.5370031595230103
# ( even ) similarity: 0.5331258177757263
# ( long ) similarity: 0.508712649345398
# opposite words of sunday
# ( appetizer ) similarity: 0.11570139229297638
# ( soup ) similarity: 0.09492828696966171
# ( chicken ) similarity: 0.023942187428474426
# ( much ) similarity: 0.019806303083896637
# ( crispy ) similarity: 0.01720512844622135
# ( hot ) similarity: 0.003991786856204271
# ( order ) similarity: 0.0010059514315798879
# ( small ) similarity: -0.0003269550215918571
# ( spicy ) similarity: -0.00147532531991601
# ( sandwich ) similarity: -0.0017227571224793792
# ....................................................
# similar words of year
# ( step ) similarity: 0.6309465169906616
# ( quality ) similarity: 0.5536267757415771
# ( super ) similarity: 0.5433886051177979
# ( ago ) similarity: 0.5357369184494019
# ( cheap ) similarity: 0.5225703716278076
# ( ask ) similarity: 0.49694547057151794
# ( kid ) similarity: 0.4951419234275818
# ( patio ) similarity: 0.4783955514431
# ( office ) similarity: 0.47636136412620544
# ( green ) similarity: 0.47257304191589355
# opposite words of year
# ( love ) similarity: 0.05223140865564346
# ( price ) similarity: 0.020412063226103783
# ( come ) similarity: 0.016459984704852104
# ( pizza ) similarity: 0.003219910664483905
# ( half ) similarity: -0.009024734608829021
# ( wednesday ) similarity: -0.012272422201931477
# ( slow ) similarity: -0.017657889053225517
# ( order ) similarity: -0.029889551922678947
# ( lunch ) similarity: -0.03009565733373165
# ( hour ) similarity: -0.03906770423054695
# ....................................................
# similar words of night
# ( right ) similarity: 0.6822344064712524
# ( thursday ) similarity: 0.630449652671814
# ( cash ) similarity: 0.5572846531867981
# ( slow ) similarity: 0.5458835363388062
# ( tip ) similarity: 0.5035358667373657
# ( busy ) similarity: 0.5009680390357971
# ( yelp ) similarity: 0.4879239499568939
# ( chip ) similarity: 0.4844152629375458
# ( monday ) similarity: 0.4831794500350952
# ( can ) similarity: 0.48310914635658264
# opposite words of night
# ( yum ) similarity: 0.09986159950494766
# ( spicy ) similarity: 0.06122860684990883
# ( sauce ) similarity: 0.016544589772820473
# ( soup ) similarity: 0.012743986211717129
# ( special ) similarity: -0.009076332673430443
# ( quality ) similarity: -0.01188434287905693
# ( small ) similarity: -0.0167422816157341
# ( patio ) similarity: -0.02207011543214321
# ( salad ) similarity: -0.02597658522427082
# ( option ) similarity: -0.03636029735207558
# ....................................................
# similar words of recommend
# ( highly ) similarity: 0.8479936718940735
# ( must ) similarity: 0.5463219881057739
# ( tacos ) similarity: 0.5339004397392273
# ( could ) similarity: 0.5153473019599915
# ( worth ) similarity: 0.5134487748146057
# ( thank ) similarity: 0.5036875009536743
# ( helpful ) similarity: 0.4987650215625763
# ( wednesday ) similarity: 0.4914480149745941
# ( fantastic ) similarity: 0.48265573382377625
# ( business ) similarity: 0.4722599685192108
# opposite words of recommend
# ( live ) similarity: 0.05170993134379387
# ( you ) similarity: 0.033187419176101685
# ( prepare ) similarity: 0.025553526356816292
# ( around ) similarity: 0.004838967230170965
# ( give ) similarity: -0.035715654492378235
# ( line ) similarity: -0.04070376977324486
# ( lol ) similarity: -0.05081340670585632
# ( park ) similarity: -0.053547170013189316
# ( check ) similarity: -0.055102866142988205
# ( still ) similarity: -0.05535787343978882
# ....................................................

# %%
count=0
for i in range(len(simopp)):
    print('Word: ',simopp[i])
    print('Similar:',simoppwords[count])
    count+=1
    print('Dissimilar:',simoppwords[count])
    count+=1
# Out:
# Word:  onion
# Similar: ['pickle', 'enjoy', 'beef', 'option', 'cheese', 'portion', 'chili', 'must', 'wednesday', 'choice']
# Dissimilar: ['sushi', 'nice', 'place', 'sure', 'wait', 'yet', 'office', 'that', 'get', 'seat']
# Word:  home
# Similar: ['town', 'authentic', 'pack', 'eat', 'dine', 'lot', 'come', 'selection', 'restaurant', 'style']
# Dissimilar: ['fry', 'offer', 'work', 'white', 'class', 'cream', 'shrimp', 'yum', 'busy', 'ice']
# Word:  park
# Similar: ['parking', 'cuban', 'plus', 'bean', 'option', 'next', 'patio', 'kid', 'dog', 'item']
# Dissimilar: ['beer', 'yummy', 'monday', 'server', 'end', 'bad', 'look', 'thank', 'taste', 'fish']
# Word:  wait
# Similar: ['ahead', 'less', 'minute', 'sure', 'seat', 'huge', 'long', 'use', 'quick', 'else']
# Dissimilar: ['cake', 'cold', 'store', 'spring', 'roll', 'fast', 'onion', 'much', 'try', 'start']
# Word:  brew
# Similar: ['cuban', 'bean', 'breakfast', 'option', 'italian', 'bread', 'large', 'sandwich', 'family', 'coffee']
# Dissimilar: ['would', 'could', 'show', 'say', 'street', 'get', 'helpful', 'use', 'back', 'know']
# Word:  brunch
# Similar: ['lunch', 'frozen', 'early', 'starbuck', 'beautiful', 'tip', 'end', 'must', 'many', 'saturday']
# Dissimilar: ['delicious', 'item', 'like', 'rice', 'portion', 'good', 'clean', 'new', 'dessert', 'ever']
# Word:  way
# Similar: ['else', 'thursday', 'day', 'say', 'start', 'red', 'fish', 'monday', 'today', 'omg']
# Dissimilar: ['appetizer', 'excellent', 'large', 'area', 'ask', 'selection', 'seafood', 'salad', 'section', 'sell']
# Word:  salad
# Similar: ['soup', 'sauce', 'chicken', 'quick', 'rib', 'crispy', 'seafood', 'super', 'sandwich', 'yum']
# Dissimilar: ['could', 'open', 'time', 'want', 'make', 'owner', 'bad', 'night', 'way', 'sign']
# Word:  sweet
# Similar: ['sandwich', 'pepper', 'pickle', 'steak', 'offer', 'town', 'meet', 'cuban', 'line', 'bread']
# Dissimilar: ['yelp', 'friday', 'day', 'favorite', 'monday', 'many', 'margarita', 'thursday', 'perfect', 'food']
# Word:  actually
# Similar: ['monday', 'sunday', 'long', 'anything', 'street', 'thank', 'music', 'everything', 'seem', 'open']
# Dissimilar: ['bread', 'fry', 'side', 'sauce', 'week', 'good', 'sandwich', 'cold', 'crispy', 'steak']
# Word:  selection
# Similar: ['section', 'sell', 'inside', 'tea', 'margarita', 'fantastic', 'highly', 'area', 'location', 'sushi']
# Dissimilar: ['line', 'else', 'saturday', 'red', 'way', 'cut', 'show', 'busy', 'fry', 'use']
# Word:  everything
# Similar: ['anything', 'every', 'even', 'nothing', 'event', 'ever', 'thing', 'actually', 'wing', 'spring']
# Dissimilar: ['steak', 'line', 'lunch', 'offer', 'bread', 'order', 'time', 'end', 'red', 'frozen']
# Word:  like
# Similar: ['know', 'bbq', 'change', 'huge', 'pepper', 'tap', 'would', 'red', 'little', 'seat']
# Dissimilar: ['always', 'family', 'brunch', 'free', 'early', 'large', 'hot', 'crowd', 'atmosphere', 'every']
# Word:  step
# Similar: ['year', 'helpful', 'starbuck', 'staff', 'stop', 'ago', 'beautiful', 'cream', 'yet', 'beef']
# Dissimilar: ['tasty', 'fill', 'pretty', 'come', 'hot', 'service', 'eat', 'half', 'dinner', 'town']
# Word:  quick
# Similar: ['snack', 'fill', 'offer', 'busy', 'ahead', 'half', 'pretty', 'salad', 'cash', 'less']
# Dissimilar: ['bad', 'lot', 'patio', 'make', 'yes', 'one', 'home', 'plus', 'town', 'location']
# Word:  drink
# Similar: ['patio', 'beef', 'margarita', 'live', 'rib', 'large', 'actually', 'half', 'music', 'style']
# Dissimilar: ['thing', 'say', 'take', 'try', 'back', 'every', 'place', 'would', 'two', 'appetizer']
# Word:  sunday
# Similar: ['day', 'monday', 'actually', 'sign', 'location', 'check', 'saturday', 'open', 'even', 'long']
# Dissimilar: ['appetizer', 'soup', 'chicken', 'much', 'crispy', 'hot', 'order', 'small', 'spicy', 'sandwich']
# Word:  year
# Similar: ['step', 'quality', 'super', 'ago', 'cheap', 'ask', 'kid', 'patio', 'office', 'green']
# Dissimilar: ['love', 'price', 'come', 'pizza', 'half', 'wednesday', 'slow', 'order', 'lunch', 'hour']
# Word:  night
# Similar: ['right', 'thursday', 'cash', 'slow', 'tip', 'busy', 'yelp', 'chip', 'monday', 'can']
# Dissimilar: ['yum', 'spicy', 'sauce', 'soup', 'special', 'quality', 'small', 'patio', 'salad', 'option']
# Word:  recommend
# Similar: ['highly', 'must', 'tacos', 'could', 'worth', 'thank', 'helpful', 'wednesday', 'fantastic', 'business']
# Dissimilar: ['live', 'you', 'prepare', 'around', 'give', 'line', 'lol', 'park', 'check', 'still']

# %% [markdown]
# ## Fast-Text Pretrained Model

# %%
pretrained_fastText_en = load_facebook_model('/kaggle/input/cc-en-300-bin/cc.en.300.bin')

# %%
simopp=[]
simoppwords=[]
for i in random_numbers:
    ww=wwords[i]
    similarwords=pretrained_fastText_en.wv.most_similar(ww, topn=10)
    oppositewords=pretrained_fastText_en.wv.most_similar(negative=ww, topn=10)
    print('similar words of',ww)
    simopp.append(ww)
    a=[]
    b=[]
    for similar,percent in similarwords:
        print('(',similar,') similarity:',percent)
        a.append(similar)
    print('opposite words of',ww)
    for opp,percent in oppositewords:
        print('(',opp,') similarity:',percent)
        b.append(opp)
    simoppwords.append(a)
    simoppwords.append(b)
    print('....................................................')
# Out:
# similar words of onion
# ( onions ) similarity: 0.8156759738922119
# ( onion. ) similarity: 0.7122210264205933
# ( garlic ) similarity: 0.69205641746521
# ( onion- ) similarity: 0.6882799863815308
# ( leek ) similarity: 0.6523008942604065
# ( onions. ) similarity: 0.6427907943725586
# ( shallots ) similarity: 0.6304621696472168
# ( onions- ) similarity: 0.6238100528717041
# ( scallion ) similarity: 0.6161937713623047
# ( bellpepper ) similarity: 0.6146571636199951
# opposite words of onion
# ( Wingspan ) similarity: 0.18997180461883545
# ( Positivo ) similarity: 0.1795070767402649
# ( Qubo ) similarity: 0.17929282784461975
# ( Projeto ) similarity: 0.17653656005859375
# ( Pelotas ) similarity: 0.1764206886291504
# ( Compatibility ) similarity: 0.17552024126052856
# ( Natal ) similarity: 0.17005963623523712
# ( NATAL ) similarity: 0.16673892736434937
# ( Novo ) similarity: 0.16502691805362701
# ( NOTINHERITED ) similarity: 0.1614864021539688
# ....................................................
# similar words of home
# ( house ) similarity: 0.6497684121131897
# ( home.The ) similarity: 0.6378366947174072
# ( home- ) similarity: 0.6096574068069458
# ( home.When ) similarity: 0.6070507764816284
# ( home.This ) similarity: 0.6065411567687988
# ( homee ) similarity: 0.6049944758415222
# ( home.So ) similarity: 0.5973572134971619
# ( home.It ) similarity: 0.5968025326728821
# ( home.While ) similarity: 0.5953359603881836
# ( home. ) similarity: 0.5911315679550171
# opposite words of home
# ( Ningauble ) similarity: 0.23594479262828827
# ( Cerebellum ) similarity: 0.2355920672416687
# ( SoWhy ) similarity: 0.23092742264270782
# ( Ymblanter ) similarity: 0.22258418798446655
# ( Masem ) similarity: 0.21933315694332123
# ( Stifle ) similarity: 0.21824383735656738
# ( Bmf ) similarity: 0.21784991025924683
# ( Alsee ) similarity: 0.21499375998973846
# ( Anmccaff ) similarity: 0.20730458199977875
# ( Sandstein ) similarity: 0.20567497611045837
# ....................................................
# similar words of park
# ( parks ) similarity: 0.7948083281517029
# ( park.The ) similarity: 0.7581489086151123
# ( park.It ) similarity: 0.7311375737190247
# ( park.This ) similarity: 0.7144930958747864
# ( park.But ) similarity: 0.7142032980918884
# ( park.As ) similarity: 0.7130081057548523
# ( park.I ) similarity: 0.7058521509170532
# ( park. ) similarity: 0.6981104612350464
# ( park.A ) similarity: 0.6955589056015015
# ( park.So ) similarity: 0.6935075521469116
# opposite words of park
# ( Zealotry ) similarity: 0.20966339111328125
# ( TORR ) similarity: 0.20714491605758667
# ( GuideTerms ) similarity: 0.2053961455821991
# ( A2X ) similarity: 0.202840194106102
# ( Amatus ) similarity: 0.19933350384235382
# ( Veracious ) similarity: 0.1982782483100891
# ( Eviscerates ) similarity: 0.19608734548091888
# ( Steth ) similarity: 0.1916320025920868
# ( JohnC5 ) similarity: 0.19024156033992767
# ( OFN ) similarity: 0.18856514990329742
# ....................................................
# similar words of wait
# ( waiting ) similarity: 0.7048940658569336
# ( wait.So ) similarity: 0.6835814118385315
# ( waited ) similarity: 0.6790311336517334
# ( WAIT ) similarity: 0.661565899848938
# ( wait. ) similarity: 0.6489719152450562
# ( wait.And ) similarity: 0.6472448706626892
# ( wait.But ) similarity: 0.6382675766944885
# ( wait.You ) similarity: 0.6104705929756165
# ( wait.I ) similarity: 0.6049072742462158
# ( paitently ) similarity: 0.5998205542564392
# opposite words of wait
# ( Coarsening ) similarity: 0.21742305159568787
# ( ENTITIES ) similarity: 0.21308960020542145
# ( ProductsBed ) similarity: 0.21295292675495148
# ( ATMOSPHERIC ) similarity: 0.21256157755851746
# ( Convex ) similarity: 0.2098446637392044
# ( Halloy ) similarity: 0.20908597111701965
# ( wardrobes.Bedroom ) similarity: 0.20839324593544006
# ( LINKSThe ) similarity: 0.20564790070056915
# ( tortricid ) similarity: 0.20465640723705292
# ( Erionite ) similarity: 0.20345832407474518
# ....................................................
# similar words of brew
# ( brews ) similarity: 0.8174722194671631
# ( brewed ) similarity: 0.8001163601875305
# ( brewing ) similarity: 0.7485465407371521
# ( beer ) similarity: 0.6990211009979248
# ( brew. ) similarity: 0.694909393787384
# ( brewer ) similarity: 0.6748774647712708
# ( cold-brew ) similarity: 0.6709611415863037
# ( well-brewed ) similarity: 0.6658819317817688
# ( micro-brew ) similarity: 0.6653314232826233
# ( brewers ) similarity: 0.6643065214157104
# opposite words of brew
# ( Ichthyosis ) similarity: 0.22766326367855072
# ( MONACO ) similarity: 0.2252378612756729
# ( Monaco ) similarity: 0.21775616705417633
# ( Giannina ) similarity: 0.2099742740392685
# ( SEG ) similarity: 0.20796704292297363
# ( Pangilinan ) similarity: 0.20129936933517456
# ( Monacos ) similarity: 0.20024797320365906
# ( CODDINGTON ) similarity: 0.19970838725566864
# ( gmail.comInterested ) similarity: 0.19922247529029846
# ( Khamis ) similarity: 0.19796016812324524
# ....................................................
# similar words of brunch
# ( brunches ) similarity: 0.790558934211731
# ( Brunch ) similarity: 0.7709662318229675
# ( brunchy ) similarity: 0.7613744735717773
# ( brunching ) similarity: 0.7606775164604187
# ( brunch-time ) similarity: 0.7521665692329407
# ( brunch. ) similarity: 0.7302573919296265
# ( brunched ) similarity: 0.700580894947052
# ( dinner ) similarity: 0.6768904328346252
# ( brunchers ) similarity: 0.6668363809585571
# ( post-brunch ) similarity: 0.653801441192627
# opposite words of brunch
# ( Markal ) similarity: 0.20921765267848969
# ( LITEON ) similarity: 0.2032794952392578
# ( Yokogawa ) similarity: 0.1997407078742981
# ( Zynex ) similarity: 0.19940298795700073
# ( SAFEGUARD ) similarity: 0.19794385135173798
# ( Hygroscopic ) similarity: 0.1939767748117447
# ( TXE ) similarity: 0.19396178424358368
# ( Misplacement ) similarity: 0.1936858594417572
# ( Dräger ) similarity: 0.19310243427753448
# ( Eklavya ) similarity: 0.19203360378742218
# ....................................................
# similar words of way
# ( ways ) similarity: 0.6914987564086914
# ( way.So ) similarity: 0.6040582060813904
# ( way.It ) similarity: 0.5956500172615051
# ( way.To ) similarity: 0.5915795564651489
# ( way.This ) similarity: 0.5898236632347107
# ( thing ) similarity: 0.5877518057823181
# ( way.By ) similarity: 0.5868825912475586
# ( way.Now ) similarity: 0.5842767953872681
# ( way.But ) similarity: 0.5830002427101135
# ( way--the ) similarity: 0.5812665224075317
# opposite words of way
# ( 1Center ) similarity: 0.25381234288215637
# ( SSC-1 ) similarity: 0.24009014666080475
# ( 30AM-12 ) similarity: 0.23921722173690796
# ( ED9 ) similarity: 0.2382148951292038
# ( .Acute ) similarity: 0.23615065217018127
# ( 11National ) similarity: 0.23460178077220917
# ( Haplic ) similarity: 0.23212289810180664
# ( 09-7 ) similarity: 0.23054927587509155
# ( Gonococcal ) similarity: 0.22898663580417633
# ( 10-2013 ) similarity: 0.2270369529724121
# ....................................................
# similar words of salad
# ( salads ) similarity: 0.8039515614509583
# ( salad- ) similarity: 0.7976067662239075
# ( salad.I ) similarity: 0.7773275971412659
# ( salad. ) similarity: 0.7466368079185486
# ( salad.The ) similarity: 0.7432843446731567
# ( salad.This ) similarity: 0.7301940321922302
# ( vinaigrette ) similarity: 0.7233855724334717
# ( Salad ) similarity: 0.7214764356613159
# ( coleslaw ) similarity: 0.7047596573829651
# ( vinegarette ) similarity: 0.701060950756073
# opposite words of salad
# ( Gráficos ) similarity: 0.21560224890708923
# ( Examrace ) similarity: 0.16889916360378265
# ( Vistakon ) similarity: 0.16702641546726227
# ( RatingClass ) similarity: 0.1652640998363495
# ( Bodhtree ) similarity: 0.16395151615142822
# ( 19955 ) similarity: 0.1634356677532196
# ( DetailsNational ) similarity: 0.16308195888996124
# ( Experteer ) similarity: 0.16292598843574524
# ( Aderyn ) similarity: 0.1628015637397766
# ( SideFX ) similarity: 0.1607748419046402
# ....................................................
# similar words of sweet
# ( super-sweet ) similarity: 0.70549076795578
# ( sweeet ) similarity: 0.6834772229194641
# ( sweet.This ) similarity: 0.6768178939819336
# ( sweet-sweet ) similarity: 0.6767272353172302
# ( -sweet ) similarity: 0.676287055015564
# ( oh-so-sweet ) similarity: 0.673732578754425
# ( sweetest ) similarity: 0.6658281683921814
# ( not-so-sweet ) similarity: 0.6544377207756042
# ( sweet.It ) similarity: 0.6501380801200867
# ( sweet.The ) similarity: 0.6483494639396667
# opposite words of sweet
# ( 10Give ) similarity: 0.21919991075992584
# ( MULT ) similarity: 0.20462286472320557
# ( LA21 ) similarity: 0.2011622190475464
# ( NWHI ) similarity: 0.1942427009344101
# ( BRWRA ) similarity: 0.1909090131521225
# ( Metropolitan ) similarity: 0.18794924020767212
# ( CDLR ) similarity: 0.18689459562301636
# ( 7.2.6 ) similarity: 0.18655715882778168
# ( area.3 ) similarity: 0.18625855445861816
# ( INCOM ) similarity: 0.18541809916496277
# ....................................................
# similar words of actually
# ( acutally ) similarity: 0.7529869079589844
# ( really ) similarity: 0.73396235704422
# ( ACTUALLY ) similarity: 0.715717077255249
# ( actuallly ) similarity: 0.7149984240531921
# ( obviously ) similarity: 0.7067629098892212
# ( actaully ) similarity: 0.6945446729660034
# ( just ) similarity: 0.6786653399467468
# ( probably ) similarity: 0.6703424453735352
# ( actally ) similarity: 0.6684151887893677
# ( supposedly ) similarity: 0.6565207839012146
# opposite words of actually
# ( Information3 ) similarity: 0.25377264618873596
# ( Events2 ) similarity: 0.25103867053985596
# ( EventsSports ) similarity: 0.24731846153736115
# ( AdmissionsNew ) similarity: 0.23182998597621918
# ( Information2 ) similarity: 0.23086802661418915
# ( CartSearch ) similarity: 0.23028969764709473
# ( PicturesPHOTOS ) similarity: 0.2298225611448288
# ( ToursTour ) similarity: 0.22850413620471954
# ( SocietyContact ) similarity: 0.22565050423145294
# ( by7 ) similarity: 0.22314074635505676
# ....................................................
# similar words of selection
# ( selections ) similarity: 0.7709962725639343
# ( selction ) similarity: 0.7471551895141602
# ( selection.The ) similarity: 0.6985617876052856
# ( Selection ) similarity: 0.6841694116592407
# ( selectio ) similarity: 0.6802212595939636
# ( slection ) similarity: 0.665911078453064
# ( seletion ) similarity: 0.6529404520988464
# ( selectionThe ) similarity: 0.6327006816864014
# ( selecton ) similarity: 0.6149122714996338
# ( selection.In ) similarity: 0.6142478585243225
# opposite words of selection
# ( HarrySquatter ) similarity: 0.21954753994941711
# ( Plasmius ) similarity: 0.21733398735523224
# ( JGalt ) similarity: 0.2170790284872055
# ( 11-13-12 ) similarity: 0.21253158152103424
# ( 39413940 ) similarity: 0.20720700919628143
# ( Sepo ) similarity: 0.20651662349700928
# ( Jan8 ) similarity: 0.20619451999664307
# ( Irridium ) similarity: 0.2055615484714508
# ( 5-14-17 ) similarity: 0.2052760273218155
# ( sethstorm ) similarity: 0.20509381592273712
# ....................................................
# similar words of everything
# ( everthing ) similarity: 0.7765555381774902
# ( eveything ) similarity: 0.7655134797096252
# ( Everything ) similarity: 0.7481933832168579
# ( everyting ) similarity: 0.7332122921943665
# ( everyhing ) similarity: 0.7275962829589844
# ( everyhting ) similarity: 0.7264785766601562
# ( everythign ) similarity: 0.7158479690551758
# ( EVERYTHING ) similarity: 0.7146450877189636
# ( everythig ) similarity: 0.6960649490356445
# ( evrything ) similarity: 0.6875240802764893
# opposite words of everything
# ( ISSX ) similarity: 0.24073098599910736
# ( Award5 ) similarity: 0.21878309547901154
# ( 0672 ) similarity: 0.21171753108501434
# ( PLURONIC ) similarity: 0.2058105170726776
# ( Longitudinal ) similarity: 0.20524919033050537
# ( 2014Nov ) similarity: 0.20502471923828125
# ( UniversityFaculty ) similarity: 0.2031441628932953
# ( studies1 ) similarity: 0.2015567421913147
# ( machine.Clamping ) similarity: 0.20086997747421265
# ( Econometric ) similarity: 0.20033270120620728
# ....................................................
# similar words of like
# ( lke ) similarity: 0.7078308463096619
# ( llike ) similarity: 0.6998098492622375
# ( think ) similarity: 0.6678071618080139
# ( lilke ) similarity: 0.6568898558616638
# ( just ) similarity: 0.6301590800285339
# ( liek ) similarity: 0.6209032535552979
# ( really ) similarity: 0.6130277514457703
# ( feel ) similarity: 0.6082065105438232
# ( something ) similarity: 0.6041772961616516
# ( want ) similarity: 0.6008815169334412
# opposite words of like
# ( EHAC ) similarity: 0.23100125789642334
# ( LocationPrivate ) similarity: 0.2152147889137268
# ( StoriesRelated ) similarity: 0.20782527327537537
# ( 1al ) similarity: 0.20204803347587585
# ( Decem- ) similarity: 0.19997623562812805
# ( IndustryTop ) similarity: 0.19823183119297028
# ( ContentAbout ) similarity: 0.1961362659931183
# ( Opslag ) similarity: 0.19595617055892944
# ( report11 ) similarity: 0.19542454183101654
# ( production6 ) similarity: 0.19426152110099792
# ....................................................
# similar words of step
# ( steps ) similarity: 0.7215865254402161
# ( step.The ) similarity: 0.6366394758224487
# ( step.So ) similarity: 0.6349491477012634
# ( step. ) similarity: 0.626663088798523
# ( step-- ) similarity: 0.6131572127342224
# ( step.It ) similarity: 0.611104428768158
# ( step.This ) similarity: 0.5999739766120911
# ( step.I ) similarity: 0.5966174006462097
# ( step.In ) similarity: 0.5943990349769592
# ( Step ) similarity: 0.5916359424591064
# opposite words of step
# ( experiencesMurder ) similarity: 0.2387872040271759
# ( .Notable ) similarity: 0.22315607964992523
# ( Otherground ) similarity: 0.2210547924041748
# ( GULLIVER ) similarity: 0.22029884159564972
# ( LawyersNotary ) similarity: 0.21952775120735168
# ( AlumniFamous ) similarity: 0.2177644819021225
# ( GROUPSFamous ) similarity: 0.21766731142997742
# ( --CHRISTIAN ) similarity: 0.21343787014484406
# ( VARIOUS ) similarity: 0.21068695187568665
# ( COPYRIGHTAll ) similarity: 0.20843610167503357
# ....................................................
# similar words of quick
# ( quck ) similarity: 0.7219973802566528
# ( super-quick ) similarity: 0.7031731009483337
# ( easy ) similarity: 0.7005500793457031
# ( qucik ) similarity: 0.6582812070846558
# ( quicky ) similarity: 0.6388074159622192
# ( not-so-quick ) similarity: 0.6295413374900818
# ( quick-ish ) similarity: 0.6193777918815613
# ( aquick ) similarity: 0.5977166891098022
# ( swift ) similarity: 0.5971460938453674
# ( quickish ) similarity: 0.5887526869773865
# opposite words of quick
# ( JJ50 ) similarity: 0.20913812518119812
# ( extra13 ) similarity: 0.20831511914730072
# ( CHDM ) similarity: 0.20773786306381226
# ( VUH ) similarity: 0.2062588781118393
# ( title16 ) similarity: 0.20501142740249634
# ( ABRAXAS ) similarity: 0.2041810303926468
# ( law.7. ) similarity: 0.20271870493888855
# ( imagecache5d.allposters.com ) similarity: 0.20236533880233765
# ( Σελίδα ) similarity: 0.20126621425151825
# ( extra12 ) similarity: 0.20057813823223114
# ....................................................
# similar words of drink
# ( drinks ) similarity: 0.8155072331428528
# ( drinking ) similarity: 0.7225548028945923
# ( drink.I ) similarity: 0.7210850715637207
# ( drank ) similarity: 0.715045690536499
# ( drink. ) similarity: 0.7126131653785706
# ( drink.And ) similarity: 0.7037104964256287
# ( drink.This ) similarity: 0.7033516764640808
# ( drink.You ) similarity: 0.6982810497283936
# ( beverage ) similarity: 0.6952994465827942
# ( drink.The ) similarity: 0.6945384740829468
# opposite words of drink
# ( SEAMS ) similarity: 0.21520183980464935
# ( End-To-End ) similarity: 0.21150243282318115
# ( 14403 ) similarity: 0.2067134976387024
# ( CoroWare ) similarity: 0.20278330147266388
# ( ITSD ) similarity: 0.20107044279575348
# ( DataPath ) similarity: 0.19910915195941925
# ( DeBlois ) similarity: 0.19754205644130707
# ( EVC ) similarity: 0.19683459401130676
# ( 15504 ) similarity: 0.1945299506187439
# ( 122009 ) similarity: 0.19302307069301605
# ....................................................
# similar words of sunday
# ( saturday ) similarity: 0.8804155588150024
# ( thursday ) similarity: 0.8333874940872192
# ( wednesday ) similarity: 0.8152494430541992
# ( monday ) similarity: 0.8039271831512451
# ( tuesday ) similarity: 0.7926559448242188
# ( friday ) similarity: 0.7851765751838684
# ( sundays ) similarity: 0.7555598616600037
# ( thrusday ) similarity: 0.7343611717224121
# ( sunday. ) similarity: 0.7291001081466675
# ( thurday ) similarity: 0.6919450759887695
# opposite words of sunday
# ( OS-1 ) similarity: 0.2057754397392273
# ( CellTrust ) similarity: 0.19594287872314453
# ( Qaleh ) similarity: 0.1914997100830078
# ( PTACs ) similarity: 0.19091053307056427
# ( TissuGlu ) similarity: 0.19033747911453247
# ( first-generation ) similarity: 0.1881749927997589
# ( user-accessible ) similarity: 0.1862189769744873
# ( Hishmeh ) similarity: 0.1857692003250122
# ( UniversityFeatured ) similarity: 0.1830713003873825
# ( Tamposi ) similarity: 0.18180079758167267
# ....................................................
# similar words of year
# ( month ) similarity: 0.7768926024436951
# ( year.This ) similarity: 0.74409419298172
# ( year.Last ) similarity: 0.6821452379226685
# ( week ) similarity: 0.6800490617752075
# ( year.Now ) similarity: 0.6705387830734253
# ( year-and ) similarity: 0.6699419021606445
# ( year.The ) similarity: 0.6682194471359253
# ( year.So ) similarity: 0.6660102009773254
# ( last ) similarity: 0.6657639741897583
# ( months ) similarity: 0.6638462543487549
# opposite words of year
# ( yourself.Get ) similarity: 0.21301831305027008
# ( toiletriesPractical ) similarity: 0.21030569076538086
# ( osmic ) similarity: 0.20231246948242188
# ( Odic ) similarity: 0.20200780034065247
# ( callsHair ) similarity: 0.1980634480714798
# ( Vnc ) similarity: 0.19775894284248352
# ( Bcd ) similarity: 0.19762089848518372
# ( Spaceeinstein ) similarity: 0.1957625150680542
# ( --Uri ) similarity: 0.19566179811954498
# ( 'Letterer ) similarity: 0.19360625743865967
# ....................................................
# similar words of night
# ( nights ) similarity: 0.7694399952888489
# ( evening ) similarity: 0.7694268226623535
# ( nite ) similarity: 0.7153534293174744
# ( night.So ) similarity: 0.7099401354789734
# ( night.The ) similarity: 0.7046819925308228
# ( night.This ) similarity: 0.6999680995941162
# ( night.It ) similarity: 0.6989587545394897
# ( night- ) similarity: 0.696759819984436
# ( night.But ) similarity: 0.6936235427856445
# ( night.Also ) similarity: 0.6895001530647278
# opposite words of night
# ( GregJackP ) similarity: 0.21056614816188812
# ( VAM ) similarity: 0.20887579023838043
# ( Extractable ) similarity: 0.20439337193965912
# ( PRECIS ) similarity: 0.1966206282377243
# ( Microsol ) similarity: 0.1958758533000946
# ( HEIDENHAIN ) similarity: 0.1933566927909851
# ( Terralingua ) similarity: 0.19183962047100067
# ( SWANsat ) similarity: 0.1912832111120224
# ( ChurchesAdd ) similarity: 0.19087208807468414
# ( Propertybase ) similarity: 0.1899472177028656
# ....................................................
# similar words of recommend
# ( reccommend ) similarity: 0.8710140585899353
# ( reccomend ) similarity: 0.8626522421836853
# ( recomend ) similarity: 0.8087084293365479
# ( recommmend ) similarity: 0.7985739707946777
# ( recommned ) similarity: 0.7864969968795776
# ( recomment ) similarity: 0.7710462808609009
# ( reommend ) similarity: 0.7709711790084839
# ( receommend ) similarity: 0.7696612477302551
# ( recommened ) similarity: 0.7640748023986816
# ( reccommed ) similarity: 0.7336115837097168
# opposite words of recommend
# ( 6March ) similarity: 0.18844346702098846
# ( 2,584 ) similarity: 0.1830778867006302
# ( todayToday ) similarity: 0.18118253350257874
# ( ContinueFiled ) similarity: 0.1799589842557907
# ( 9,019 ) similarity: 0.17944440245628357
# ( Seversky ) similarity: 0.17613933980464935
# ( RecipesStarters ) similarity: 0.17489264905452728
# ( 2012,06 ) similarity: 0.17358702421188354
# ( 15,246 ) similarity: 0.17334702610969543
# ( 1922-2014 ) similarity: 0.17314401268959045
# ....................................................

# %%
count=0
for i in range(len(simopp)):
    print('Word: ',simopp[i])
    print('Similar: ',simoppwords[count])
    count+=1
    print('Dissimilar: ',simoppwords[count])
    count+=1
# Out:
# Word:  onion
# Similar:  ['onions', 'onion.', 'garlic', 'onion-', 'leek', 'onions.', 'shallots', 'onions-', 'scallion', 'bellpepper']
# Dissimilar:  ['Wingspan', 'Positivo', 'Qubo', 'Projeto', 'Pelotas', 'Compatibility', 'Natal', 'NATAL', 'Novo', 'NOTINHERITED']
# Word:  home
# Similar:  ['house', 'home.The', 'home-', 'home.When', 'home.This', 'homee', 'home.So', 'home.It', 'home.While', 'home.']
# Dissimilar:  ['Ningauble', 'Cerebellum', 'SoWhy', 'Ymblanter', 'Masem', 'Stifle', 'Bmf', 'Alsee', 'Anmccaff', 'Sandstein']
# Word:  park
# Similar:  ['parks', 'park.The', 'park.It', 'park.This', 'park.But', 'park.As', 'park.I', 'park.', 'park.A', 'park.So']
# Dissimilar:  ['Zealotry', 'TORR', 'GuideTerms', 'A2X', 'Amatus', 'Veracious', 'Eviscerates', 'Steth', 'JohnC5', 'OFN']
# Word:  wait
# Similar:  ['waiting', 'wait.So', 'waited', 'WAIT', 'wait.', 'wait.And', 'wait.But', 'wait.You', 'wait.I', 'paitently']
# Dissimilar:  ['Coarsening', 'ENTITIES', 'ProductsBed', 'ATMOSPHERIC', 'Convex', 'Halloy', 'wardrobes.Bedroom', 'LINKSThe', 'tortricid', 'Erionite']
# Word:  brew
# Similar:  ['brews', 'brewed', 'brewing', 'beer', 'brew.', 'brewer', 'cold-brew', 'well-brewed', 'micro-brew', 'brewers']
# Dissimilar:  ['Ichthyosis', 'MONACO', 'Monaco', 'Giannina', 'SEG', 'Pangilinan', 'Monacos', 'CODDINGTON', 'gmail.comInterested', 'Khamis']
# Word:  brunch
# Similar:  ['brunches', 'Brunch', 'brunchy', 'brunching', 'brunch-time', 'brunch.', 'brunched', 'dinner', 'brunchers', 'post-brunch']
# Dissimilar:  ['Markal', 'LITEON', 'Yokogawa', 'Zynex', 'SAFEGUARD', 'Hygroscopic', 'TXE', 'Misplacement', 'Dräger', 'Eklavya']
# Word:  way
# Similar:  ['ways', 'way.So', 'way.It', 'way.To', 'way.This', 'thing', 'way.By', 'way.Now', 'way.But', 'way--the']
# Dissimilar:  ['1Center', 'SSC-1', '30AM-12', 'ED9', '.Acute', '11National', 'Haplic', '09-7', 'Gonococcal', '10-2013']
# Word:  salad
# Similar:  ['salads', 'salad-', 'salad.I', 'salad.', 'salad.The', 'salad.This', 'vinaigrette', 'Salad', 'coleslaw', 'vinegarette']
# Dissimilar:  ['Gráficos', 'Examrace', 'Vistakon', 'RatingClass', 'Bodhtree', '19955', 'DetailsNational', 'Experteer', 'Aderyn', 'SideFX']
# Word:  sweet
# Similar:  ['super-sweet', 'sweeet', 'sweet.This', 'sweet-sweet', '-sweet', 'oh-so-sweet', 'sweetest', 'not-so-sweet', 'sweet.It', 'sweet.The']
# Dissimilar:  ['10Give', 'MULT', 'LA21', 'NWHI', 'BRWRA', 'Metropolitan', 'CDLR', '7.2.6', 'area.3', 'INCOM']
# Word:  actually
# Similar:  ['acutally', 'really', 'ACTUALLY', 'actuallly', 'obviously', 'actaully', 'just', 'probably', 'actally', 'supposedly']
# Dissimilar:  ['Information3', 'Events2', 'EventsSports', 'AdmissionsNew', 'Information2', 'CartSearch', 'PicturesPHOTOS', 'ToursTour', 'SocietyContact', 'by7']
# Word:  selection
# Similar:  ['selections', 'selction', 'selection.The', 'Selection', 'selectio', 'slection', 'seletion', 'selectionThe', 'selecton', 'selection.In']
# Dissimilar:  ['HarrySquatter', 'Plasmius', 'JGalt', '11-13-12', '39413940', 'Sepo', 'Jan8', 'Irridium', '5-14-17', 'sethstorm']
# Word:  everything
# Similar:  ['everthing', 'eveything', 'Everything', 'everyting', 'everyhing', 'everyhting', 'everythign', 'EVERYTHING', 'everythig', 'evrything']
# Dissimilar:  ['ISSX', 'Award5', '0672', 'PLURONIC', 'Longitudinal', '2014Nov', 'UniversityFaculty', 'studies1', 'machine.Clamping', 'Econometric']
# Word:  like
# Similar:  ['lke', 'llike', 'think', 'lilke', 'just', 'liek', 'really', 'feel', 'something', 'want']
# Dissimilar:  ['EHAC', 'LocationPrivate', 'StoriesRelated', '1al', 'Decem-', 'IndustryTop', 'ContentAbout', 'Opslag', 'report11', 'production6']
# Word:  step
# Similar:  ['steps', 'step.The', 'step.So', 'step.', 'step--', 'step.It', 'step.This', 'step.I', 'step.In', 'Step']
# Dissimilar:  ['experiencesMurder', '.Notable', 'Otherground', 'GULLIVER', 'LawyersNotary', 'AlumniFamous', 'GROUPSFamous', '--CHRISTIAN', 'VARIOUS', 'COPYRIGHTAll']
# Word:  quick
# Similar:  ['quck', 'super-quick', 'easy', 'qucik', 'quicky', 'not-so-quick', 'quick-ish', 'aquick', 'swift', 'quickish']
# Dissimilar:  ['JJ50', 'extra13', 'CHDM', 'VUH', 'title16', 'ABRAXAS', 'law.7.', 'imagecache5d.allposters.com', 'Σελίδα', 'extra12']
# Word:  drink
# Similar:  ['drinks', 'drinking', 'drink.I', 'drank', 'drink.', 'drink.And', 'drink.This', 'drink.You', 'beverage', 'drink.The']
# Dissimilar:  ['SEAMS', 'End-To-End', '14403', 'CoroWare', 'ITSD', 'DataPath', 'DeBlois', 'EVC', '15504', '122009']
# Word:  sunday
# Similar:  ['saturday', 'thursday', 'wednesday', 'monday', 'tuesday', 'friday', 'sundays', 'thrusday', 'sunday.', 'thurday']
# Dissimilar:  ['OS-1', 'CellTrust', 'Qaleh', 'PTACs', 'TissuGlu', 'first-generation', 'user-accessible', 'Hishmeh', 'UniversityFeatured', 'Tamposi']
# Word:  year
# Similar:  ['month', 'year.This', 'year.Last', 'week', 'year.Now', 'year-and', 'year.The', 'year.So', 'last', 'months']
# Dissimilar:  ['yourself.Get', 'toiletriesPractical', 'osmic', 'Odic', 'callsHair', 'Vnc', 'Bcd', 'Spaceeinstein', '--Uri', "'Letterer"]
# Word:  night
# Similar:  ['nights', 'evening', 'nite', 'night.So', 'night.The', 'night.This', 'night.It', 'night-', 'night.But', 'night.Also']
# Dissimilar:  ['GregJackP', 'VAM', 'Extractable', 'PRECIS', 'Microsol', 'HEIDENHAIN', 'Terralingua', 'SWANsat', 'ChurchesAdd', 'Propertybase']
# Word:  recommend
# Similar:  ['reccommend', 'reccomend', 'recomend', 'recommmend', 'recommned', 'recomment', 'reommend', 'receommend', 'recommened', 'reccommed']
# Dissimilar:  ['6March', '2,584', 'todayToday', 'ContinueFiled', '9,019', 'Seversky', 'RecipesStarters', '2012,06', '15,246', '1922-2014']

# %%
pretrained_fastText_en.build_vocab(wwords, update = True)

# %%
pretrained_fastText_en.train(wwords, total_examples=pretrained_fastText_en.corpus_count, epochs=100)
# Out:
# (2461, 135800)

# %%
for i in random_numbers:
    ww=wwords[i]
    similarwords=pretrained_fastText_en.wv.most_similar(ww, topn=10)
    oppositewords=pretrained_fastText_en.wv.most_similar(negative=ww, topn=10)
    print('similar words of',ww)
    for similar,percent in similarwords:
        print('(',similar,') similarity:',percent)
    print('opposite words of',ww)
    for opp,percent in oppositewords:
        print('(',opp,') similarity:',percent)
    print('....................................................')
# Out:
# similar words of onion
# ( onions ) similarity: 0.8156759738922119
# ( onion. ) similarity: 0.7122210264205933
# ( garlic ) similarity: 0.69205641746521
# ( onion- ) similarity: 0.6882799863815308
# ( leek ) similarity: 0.6523008942604065
# ( onions. ) similarity: 0.6427907943725586
# ( shallots ) similarity: 0.6304621696472168
# ( onions- ) similarity: 0.6238100528717041
# ( scallion ) similarity: 0.6161937713623047
# ( bellpepper ) similarity: 0.6146571636199951
# opposite words of onion
# ( Wingspan ) similarity: 0.18997180461883545
# ( Positivo ) similarity: 0.1795070767402649
# ( Qubo ) similarity: 0.17929282784461975
# ( Projeto ) similarity: 0.17653656005859375
# ( Pelotas ) similarity: 0.1764206886291504
# ( Compatibility ) similarity: 0.17552024126052856
# ( Natal ) similarity: 0.17005963623523712
# ( NATAL ) similarity: 0.16673892736434937
# ( Novo ) similarity: 0.16502691805362701
# ( NOTINHERITED ) similarity: 0.1614864021539688
# ....................................................
# similar words of home
# ( house ) similarity: 0.6497684121131897
# ( home.The ) similarity: 0.6378366947174072
# ( home- ) similarity: 0.6096574068069458
# ( home.When ) similarity: 0.6070507764816284
# ( home.This ) similarity: 0.6065411567687988
# ( homee ) similarity: 0.6049944758415222
# ( home.So ) similarity: 0.5973572134971619
# ( home.It ) similarity: 0.5968025326728821
# ( home.While ) similarity: 0.5953359603881836
# ( home. ) similarity: 0.5911315679550171
# opposite words of home
# ( Ningauble ) similarity: 0.23594479262828827
# ( Cerebellum ) similarity: 0.2355920672416687
# ( SoWhy ) similarity: 0.23092742264270782
# ( Ymblanter ) similarity: 0.22258418798446655
# ( Masem ) similarity: 0.21933315694332123
# ( Stifle ) similarity: 0.21824383735656738
# ( Bmf ) similarity: 0.21784991025924683
# ( Alsee ) similarity: 0.21499375998973846
# ( Anmccaff ) similarity: 0.20730458199977875
# ( Sandstein ) similarity: 0.20567497611045837
# ....................................................
# similar words of park
# ( parks ) similarity: 0.7948083281517029
# ( park.The ) similarity: 0.7581489086151123
# ( park.It ) similarity: 0.7311375737190247
# ( park.This ) similarity: 0.7144930958747864
# ( park.But ) similarity: 0.7142032980918884
# ( park.As ) similarity: 0.7130081057548523
# ( park.I ) similarity: 0.7058521509170532
# ( park. ) similarity: 0.6981104612350464
# ( park.A ) similarity: 0.6955589056015015
# ( park.So ) similarity: 0.6935075521469116
# opposite words of park
# ( Zealotry ) similarity: 0.20966339111328125
# ( TORR ) similarity: 0.20714491605758667
# ( GuideTerms ) similarity: 0.2053961455821991
# ( A2X ) similarity: 0.202840194106102
# ( Amatus ) similarity: 0.19933350384235382
# ( Veracious ) similarity: 0.1982782483100891
# ( Eviscerates ) similarity: 0.19608734548091888
# ( Steth ) similarity: 0.1916320025920868
# ( JohnC5 ) similarity: 0.19024156033992767
# ( OFN ) similarity: 0.18856514990329742
# ....................................................
# similar words of wait
# ( waiting ) similarity: 0.7048940658569336
# ( wait.So ) similarity: 0.6835814118385315
# ( waited ) similarity: 0.6790311336517334
# ( WAIT ) similarity: 0.661565899848938
# ( wait. ) similarity: 0.6489719152450562
# ( wait.And ) similarity: 0.6472448706626892
# ( wait.But ) similarity: 0.6382675766944885
# ( wait.You ) similarity: 0.6104705929756165
# ( wait.I ) similarity: 0.6049072742462158
# ( paitently ) similarity: 0.5998205542564392
# opposite words of wait
# ( Coarsening ) similarity: 0.21742305159568787
# ( ENTITIES ) similarity: 0.21308960020542145
# ( ProductsBed ) similarity: 0.21295292675495148
# ( ATMOSPHERIC ) similarity: 0.21256157755851746
# ( Convex ) similarity: 0.2098446637392044
# ( Halloy ) similarity: 0.20908597111701965
# ( wardrobes.Bedroom ) similarity: 0.20839324593544006
# ( LINKSThe ) similarity: 0.20564790070056915
# ( tortricid ) similarity: 0.20465640723705292
# ( Erionite ) similarity: 0.20345832407474518
# ....................................................
# similar words of brew
# ( brews ) similarity: 0.8174722194671631
# ( brewed ) similarity: 0.8001163601875305
# ( brewing ) similarity: 0.7485465407371521
# ( beer ) similarity: 0.6990211009979248
# ( brew. ) similarity: 0.694909393787384
# ( brewer ) similarity: 0.6748774647712708
# ( cold-brew ) similarity: 0.6709611415863037
# ( well-brewed ) similarity: 0.6658819317817688
# ( micro-brew ) similarity: 0.6653314232826233
# ( brewers ) similarity: 0.6643065214157104
# opposite words of brew
# ( Ichthyosis ) similarity: 0.22766326367855072
# ( MONACO ) similarity: 0.2252378612756729
# ( Monaco ) similarity: 0.21775616705417633
# ( Giannina ) similarity: 0.2099742740392685
# ( SEG ) similarity: 0.20796704292297363
# ( Pangilinan ) similarity: 0.20129936933517456
# ( Monacos ) similarity: 0.20024797320365906
# ( CODDINGTON ) similarity: 0.19970838725566864
# ( gmail.comInterested ) similarity: 0.19922247529029846
# ( Khamis ) similarity: 0.19796016812324524
# ....................................................
# similar words of brunch
# ( brunches ) similarity: 0.790558934211731
# ( Brunch ) similarity: 0.7709662318229675
# ( brunchy ) similarity: 0.7613744735717773
# ( brunching ) similarity: 0.7606775164604187
# ( brunch-time ) similarity: 0.7521665692329407
# ( brunch. ) similarity: 0.7302573919296265
# ( brunched ) similarity: 0.700580894947052
# ( dinner ) similarity: 0.6768904328346252
# ( brunchers ) similarity: 0.6668363809585571
# ( post-brunch ) similarity: 0.653801441192627
# opposite words of brunch
# ( Markal ) similarity: 0.20921765267848969
# ( LITEON ) similarity: 0.2032794952392578
# ( Yokogawa ) similarity: 0.1997407078742981
# ( Zynex ) similarity: 0.19940298795700073
# ( SAFEGUARD ) similarity: 0.19794385135173798
# ( Hygroscopic ) similarity: 0.1939767748117447
# ( TXE ) similarity: 0.19396178424358368
# ( Misplacement ) similarity: 0.1936858594417572
# ( Dräger ) similarity: 0.19310243427753448
# ( Eklavya ) similarity: 0.19203360378742218
# ....................................................
# similar words of way
# ( ways ) similarity: 0.6914987564086914
# ( way.So ) similarity: 0.6040582060813904
# ( way.It ) similarity: 0.5956500172615051
# ( way.To ) similarity: 0.5915795564651489
# ( way.This ) similarity: 0.5898236632347107
# ( thing ) similarity: 0.5877518057823181
# ( way.By ) similarity: 0.5868825912475586
# ( way.Now ) similarity: 0.5842767953872681
# ( way.But ) similarity: 0.5830002427101135
# ( way--the ) similarity: 0.5812665224075317
# opposite words of way
# ( 1Center ) similarity: 0.25381234288215637
# ( SSC-1 ) similarity: 0.24009014666080475
# ( 30AM-12 ) similarity: 0.23921722173690796
# ( ED9 ) similarity: 0.2382148951292038
# ( .Acute ) similarity: 0.23615065217018127
# ( 11National ) similarity: 0.23460178077220917
# ( Haplic ) similarity: 0.23212289810180664
# ( 09-7 ) similarity: 0.23054927587509155
# ( Gonococcal ) similarity: 0.22898663580417633
# ( 10-2013 ) similarity: 0.2270369529724121
# ....................................................
# similar words of salad
# ( salads ) similarity: 0.8039515614509583
# ( salad- ) similarity: 0.7976067662239075
# ( salad.I ) similarity: 0.7773275971412659
# ( salad. ) similarity: 0.7466368079185486
# ( salad.The ) similarity: 0.7432843446731567
# ( salad.This ) similarity: 0.7301940321922302
# ( vinaigrette ) similarity: 0.7233855724334717
# ( Salad ) similarity: 0.7214764356613159
# ( coleslaw ) similarity: 0.7047596573829651
# ( vinegarette ) similarity: 0.701060950756073
# opposite words of salad
# ( Gráficos ) similarity: 0.21560224890708923
# ( Examrace ) similarity: 0.16889916360378265
# ( Vistakon ) similarity: 0.16702641546726227
# ( RatingClass ) similarity: 0.1652640998363495
# ( Bodhtree ) similarity: 0.16395151615142822
# ( 19955 ) similarity: 0.1634356677532196
# ( DetailsNational ) similarity: 0.16308195888996124
# ( Experteer ) similarity: 0.16292598843574524
# ( Aderyn ) similarity: 0.1628015637397766
# ( SideFX ) similarity: 0.1607748419046402
# ....................................................
# similar words of sweet
# ( super-sweet ) similarity: 0.70549076795578
# ( sweeet ) similarity: 0.6834772229194641
# ( sweet.This ) similarity: 0.6768178939819336
# ( sweet-sweet ) similarity: 0.6767272353172302
# ( -sweet ) similarity: 0.676287055015564
# ( oh-so-sweet ) similarity: 0.673732578754425
# ( sweetest ) similarity: 0.6658281683921814
# ( not-so-sweet ) similarity: 0.6544377207756042
# ( sweet.It ) similarity: 0.6501380801200867
# ( sweet.The ) similarity: 0.6483494639396667
# opposite words of sweet
# ( 10Give ) similarity: 0.21919991075992584
# ( MULT ) similarity: 0.20462286472320557
# ( LA21 ) similarity: 0.2011622190475464
# ( NWHI ) similarity: 0.1942427009344101
# ( BRWRA ) similarity: 0.1909090131521225
# ( Metropolitan ) similarity: 0.18794924020767212
# ( CDLR ) similarity: 0.18689459562301636
# ( 7.2.6 ) similarity: 0.18655715882778168
# ( area.3 ) similarity: 0.18625855445861816
# ( INCOM ) similarity: 0.18541809916496277
# ....................................................
# similar words of actually
# ( acutally ) similarity: 0.7529869079589844
# ( really ) similarity: 0.73396235704422
# ( ACTUALLY ) similarity: 0.715717077255249
# ( actuallly ) similarity: 0.7149984240531921
# ( obviously ) similarity: 0.7067629098892212
# ( actaully ) similarity: 0.6945446729660034
# ( just ) similarity: 0.6786653399467468
# ( probably ) similarity: 0.6703424453735352
# ( actally ) similarity: 0.6684151887893677
# ( supposedly ) similarity: 0.6565207839012146
# opposite words of actually
# ( Information3 ) similarity: 0.25377264618873596
# ( Events2 ) similarity: 0.25103867053985596
# ( EventsSports ) similarity: 0.24731846153736115
# ( AdmissionsNew ) similarity: 0.23182998597621918
# ( Information2 ) similarity: 0.23086802661418915
# ( CartSearch ) similarity: 0.23028969764709473
# ( PicturesPHOTOS ) similarity: 0.2298225611448288
# ( ToursTour ) similarity: 0.22850413620471954
# ( SocietyContact ) similarity: 0.22565050423145294
# ( by7 ) similarity: 0.22314074635505676
# ....................................................
# similar words of selection
# ( selections ) similarity: 0.7709962725639343
# ( selction ) similarity: 0.7471551895141602
# ( selection.The ) similarity: 0.6985617876052856
# ( Selection ) similarity: 0.6841694116592407
# ( selectio ) similarity: 0.6802212595939636
# ( slection ) similarity: 0.665911078453064
# ( seletion ) similarity: 0.6529404520988464
# ( selectionThe ) similarity: 0.6327006816864014
# ( selecton ) similarity: 0.6149122714996338
# ( selection.In ) similarity: 0.6142478585243225
# opposite words of selection
# ( HarrySquatter ) similarity: 0.21954753994941711
# ( Plasmius ) similarity: 0.21733398735523224
# ( JGalt ) similarity: 0.2170790284872055
# ( 11-13-12 ) similarity: 0.21253158152103424
# ( 39413940 ) similarity: 0.20720700919628143
# ( Sepo ) similarity: 0.20651662349700928
# ( Jan8 ) similarity: 0.20619451999664307
# ( Irridium ) similarity: 0.2055615484714508
# ( 5-14-17 ) similarity: 0.2052760273218155
# ( sethstorm ) similarity: 0.20509381592273712
# ....................................................
# similar words of everything
# ( everthing ) similarity: 0.7765555381774902
# ( eveything ) similarity: 0.7655134797096252
# ( Everything ) similarity: 0.7481933832168579
# ( everyting ) similarity: 0.7332122921943665
# ( everyhing ) similarity: 0.7275962829589844
# ( everyhting ) similarity: 0.7264785766601562
# ( everythign ) similarity: 0.7158479690551758
# ( EVERYTHING ) similarity: 0.7146450877189636
# ( everythig ) similarity: 0.6960649490356445
# ( evrything ) similarity: 0.6875240802764893
# opposite words of everything
# ( ISSX ) similarity: 0.24073098599910736
# ( Award5 ) similarity: 0.21878309547901154
# ( 0672 ) similarity: 0.21171753108501434
# ( PLURONIC ) similarity: 0.2058105170726776
# ( Longitudinal ) similarity: 0.20524919033050537
# ( 2014Nov ) similarity: 0.20502471923828125
# ( UniversityFaculty ) similarity: 0.2031441628932953
# ( studies1 ) similarity: 0.2015567421913147
# ( machine.Clamping ) similarity: 0.20086997747421265
# ( Econometric ) similarity: 0.20033270120620728
# ....................................................
# similar words of like
# ( lke ) similarity: 0.7078308463096619
# ( llike ) similarity: 0.6998098492622375
# ( think ) similarity: 0.6678071618080139
# ( lilke ) similarity: 0.6568898558616638
# ( just ) similarity: 0.6301590800285339
# ( liek ) similarity: 0.6209032535552979
# ( really ) similarity: 0.6130277514457703
# ( feel ) similarity: 0.6082065105438232
# ( something ) similarity: 0.6041772961616516
# ( want ) similarity: 0.6008815169334412
# opposite words of like
# ( EHAC ) similarity: 0.23100125789642334
# ( LocationPrivate ) similarity: 0.2152147889137268
# ( StoriesRelated ) similarity: 0.20782527327537537
# ( 1al ) similarity: 0.20204803347587585
# ( Decem- ) similarity: 0.19997623562812805
# ( IndustryTop ) similarity: 0.19823183119297028
# ( ContentAbout ) similarity: 0.1961362659931183
# ( Opslag ) similarity: 0.19595617055892944
# ( report11 ) similarity: 0.19542454183101654
# ( production6 ) similarity: 0.19426152110099792
# ....................................................
# similar words of step
# ( steps ) similarity: 0.7215865254402161
# ( step.The ) similarity: 0.6366394758224487
# ( step.So ) similarity: 0.6349491477012634
# ( step. ) similarity: 0.626663088798523
# ( step-- ) similarity: 0.6131572127342224
# ( step.It ) similarity: 0.611104428768158
# ( step.This ) similarity: 0.5999739766120911
# ( step.I ) similarity: 0.5966174006462097
# ( step.In ) similarity: 0.5943990349769592
# ( Step ) similarity: 0.5916359424591064
# opposite words of step
# ( experiencesMurder ) similarity: 0.2387872040271759
# ( .Notable ) similarity: 0.22315607964992523
# ( Otherground ) similarity: 0.2210547924041748
# ( GULLIVER ) similarity: 0.22029884159564972
# ( LawyersNotary ) similarity: 0.21952775120735168
# ( AlumniFamous ) similarity: 0.2177644819021225
# ( GROUPSFamous ) similarity: 0.21766731142997742
# ( --CHRISTIAN ) similarity: 0.21343787014484406
# ( VARIOUS ) similarity: 0.21068695187568665
# ( COPYRIGHTAll ) similarity: 0.20843610167503357
# ....................................................
# similar words of quick
# ( quck ) similarity: 0.7219973802566528
# ( super-quick ) similarity: 0.7031731009483337
# ( easy ) similarity: 0.7005500793457031
# ( qucik ) similarity: 0.6582812070846558
# ( quicky ) similarity: 0.6388074159622192
# ( not-so-quick ) similarity: 0.6295413374900818
# ( quick-ish ) similarity: 0.6193777918815613
# ( aquick ) similarity: 0.5977166891098022
# ( swift ) similarity: 0.5971460938453674
# ( quickish ) similarity: 0.5887526869773865
# opposite words of quick
# ( JJ50 ) similarity: 0.20913812518119812
# ( extra13 ) similarity: 0.20831511914730072
# ( CHDM ) similarity: 0.20773786306381226
# ( VUH ) similarity: 0.2062588781118393
# ( title16 ) similarity: 0.20501142740249634
# ( ABRAXAS ) similarity: 0.2041810303926468
# ( law.7. ) similarity: 0.20271870493888855
# ( imagecache5d.allposters.com ) similarity: 0.20236533880233765
# ( Σελίδα ) similarity: 0.20126621425151825
# ( extra12 ) similarity: 0.20057813823223114
# ....................................................
# similar words of drink
# ( drinks ) similarity: 0.8155072331428528
# ( drinking ) similarity: 0.7225548028945923
# ( drink.I ) similarity: 0.7210850715637207
# ( drank ) similarity: 0.715045690536499
# ( drink. ) similarity: 0.7126131653785706
# ( drink.And ) similarity: 0.7037104964256287
# ( drink.This ) similarity: 0.7033516764640808
# ( drink.You ) similarity: 0.6982810497283936
# ( beverage ) similarity: 0.6952994465827942
# ( drink.The ) similarity: 0.6945384740829468
# opposite words of drink
# ( SEAMS ) similarity: 0.21520183980464935
# ( End-To-End ) similarity: 0.21150243282318115
# ( 14403 ) similarity: 0.2067134976387024
# ( CoroWare ) similarity: 0.20278330147266388
# ( ITSD ) similarity: 0.20107044279575348
# ( DataPath ) similarity: 0.19910915195941925
# ( DeBlois ) similarity: 0.19754205644130707
# ( EVC ) similarity: 0.19683459401130676
# ( 15504 ) similarity: 0.1945299506187439
# ( 122009 ) similarity: 0.19302307069301605
# ....................................................
# similar words of sunday
# ( saturday ) similarity: 0.8804155588150024
# ( thursday ) similarity: 0.8333874940872192
# ( wednesday ) similarity: 0.8152494430541992
# ( monday ) similarity: 0.8039271831512451
# ( tuesday ) similarity: 0.7926559448242188
# ( friday ) similarity: 0.7851765751838684
# ( sundays ) similarity: 0.7555598616600037
# ( thrusday ) similarity: 0.7343611717224121
# ( sunday. ) similarity: 0.7291001081466675
# ( thurday ) similarity: 0.6919450759887695
# opposite words of sunday
# ( OS-1 ) similarity: 0.2057754397392273
# ( CellTrust ) similarity: 0.19594287872314453
# ( Qaleh ) similarity: 0.1914997100830078
# ( PTACs ) similarity: 0.19091053307056427
# ( TissuGlu ) similarity: 0.19033747911453247
# ( first-generation ) similarity: 0.1881749927997589
# ( user-accessible ) similarity: 0.1862189769744873
# ( Hishmeh ) similarity: 0.1857692003250122
# ( UniversityFeatured ) similarity: 0.1830713003873825
# ( Tamposi ) similarity: 0.18180079758167267
# ....................................................
# similar words of year
# ( month ) similarity: 0.7768926024436951
# ( year.This ) similarity: 0.74409419298172
# ( year.Last ) similarity: 0.6821452379226685
# ( week ) similarity: 0.6800490617752075
# ( year.Now ) similarity: 0.6705387830734253
# ( year-and ) similarity: 0.6699419021606445
# ( year.The ) similarity: 0.6682194471359253
# ( year.So ) similarity: 0.6660102009773254
# ( last ) similarity: 0.6657639741897583
# ( months ) similarity: 0.6638462543487549
# opposite words of year
# ( yourself.Get ) similarity: 0.21301831305027008
# ( toiletriesPractical ) similarity: 0.21030569076538086
# ( osmic ) similarity: 0.20231246948242188
# ( Odic ) similarity: 0.20200780034065247
# ( callsHair ) similarity: 0.1980634480714798
# ( Vnc ) similarity: 0.19775894284248352
# ( Bcd ) similarity: 0.19762089848518372
# ( Spaceeinstein ) similarity: 0.1957625150680542
# ( --Uri ) similarity: 0.19566179811954498
# ( 'Letterer ) similarity: 0.19360625743865967
# ....................................................
# similar words of night
# ( nights ) similarity: 0.7694399952888489
# ( evening ) similarity: 0.7694268226623535
# ( nite ) similarity: 0.7153534293174744
# ( night.So ) similarity: 0.7099401354789734
# ( night.The ) similarity: 0.7046819925308228
# ( night.This ) similarity: 0.6999680995941162
# ( night.It ) similarity: 0.6989587545394897
# ( night- ) similarity: 0.696759819984436
# ( night.But ) similarity: 0.6936235427856445
# ( night.Also ) similarity: 0.6895001530647278
# opposite words of night
# ( GregJackP ) similarity: 0.21056614816188812
# ( VAM ) similarity: 0.20887579023838043
# ( Extractable ) similarity: 0.20439337193965912
# ( PRECIS ) similarity: 0.1966206282377243
# ( Microsol ) similarity: 0.1958758533000946
# ( HEIDENHAIN ) similarity: 0.1933566927909851
# ( Terralingua ) similarity: 0.19183962047100067
# ( SWANsat ) similarity: 0.1912832111120224
# ( ChurchesAdd ) similarity: 0.19087208807468414
# ( Propertybase ) similarity: 0.1899472177028656
# ....................................................
# similar words of recommend
# ( reccommend ) similarity: 0.8710140585899353
# ( reccomend ) similarity: 0.8626522421836853
# ( recomend ) similarity: 0.8087084293365479
# ( recommmend ) similarity: 0.7985739707946777
# ( recommned ) similarity: 0.7864969968795776
# ( recomment ) similarity: 0.7710462808609009
# ( reommend ) similarity: 0.7709711790084839
# ( receommend ) similarity: 0.7696612477302551
# ( recommened ) similarity: 0.7640748023986816
# ( reccommed ) similarity: 0.7336115837097168
# opposite words of recommend
# ( 6March ) similarity: 0.18844346702098846
# ( 2,584 ) similarity: 0.1830778867006302
# ( todayToday ) similarity: 0.18118253350257874
# ( ContinueFiled ) similarity: 0.1799589842557907
# ( 9,019 ) similarity: 0.17944440245628357
# ( Seversky ) similarity: 0.17613933980464935
# ( RecipesStarters ) similarity: 0.17489264905452728
# ( 2012,06 ) similarity: 0.17358702421188354
# ( 15,246 ) similarity: 0.17334702610969543
# ( 1922-2014 ) similarity: 0.17314401268959045
# ....................................................
